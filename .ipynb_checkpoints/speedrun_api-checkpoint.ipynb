# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import seaborn as sns

# %%
base_url = 'https://www.speedrun.com/api/v1/games'
game_name = 'elden_ring'

response = requests.get(f'{base_url}?name={game_name}')
data = response.json()

# The game ID should be in the returned data
game_id = data['data'][0]['id']
game_id
# Out:
# 'nd28z0ed'

# %%
base_url = 'https://www.speedrun.com/api/v1/runs'
status = 'verified'
category = 'Any_Glitchless-PC'
orderby = 'date'
direction = 'desc'
max_results = 10  # Maximum results per page
total_results = 1000  # Total results to fetch
game_id = 'nd28z0ed'  # Game ID

# Create an empty list to store the extracted data
extracted_data = []

# Calculate the number of pages to fetch
pages = total_results // max_results

# Fetch each page of results
for page in range(pages):
    offset = page * max_results
    response = requests.get(f'{base_url}?game={game_id}&status={status}&category={category}&orderby={orderby}&direction={direction}&max={max_results}&offset={offset}')
    data = response.json()

    # Extract the fields from each run and add them to the list
    for run in data['data']:
        date = run['date']
        submitted = run['submitted']
        verified = run['status']['status']
        primary_t = run['times']['primary_t']
        realtime_t = run['times']['realtime_t']
        extracted_data.append([date, submitted, verified, primary_t, realtime_t])

    # Print a message to show the progress
    print(f'Page {page + 1} of {pages} processed.')

# Convert the list to a DataFrame
df = pd.DataFrame(extracted_data, columns=['Date', 'Submitted', 'Verified', 'Primary_t', 'Realtime_t'])
df

# %%
# Save the DataFrame to a CSV file
df.to_csv('eldenring_speedrun_data.csv', index=False)

# %%
# Load the data from the CSV file into a new df
csv_df = pd.read_csv('eldenring_speedrun_data.csv')

# %%
# Convert the 'Date' column to datetime
csv_df['Date'] = pd.to_datetime(csv_df['Date'])

# Define a threshold for the maximum 'Realtime_t' value
threshold = csv_df['Realtime_t'].quantile(0.99)  # Adjust this value as needed

# Remove rows where 'Realtime_t' is above the threshold
csv_df = csv_df[csv_df['Realtime_t'] <= threshold]

# Convert dates to numbers so they can be used in polyfit
dates = mdates.date2num(csv_df['Date'])

# Fit a line to the data
coefficients = np.polyfit(dates, csv_df['Realtime_t'], 1)
polynomial = np.poly1d(coefficients)

# Generate y-values for the trendline
trendline = polynomial(dates)

# Create a new figure and axes
fig, ax = plt.subplots()

# Plot the data and the trendline
ax.plot_date(csv_df['Date'], csv_df['Realtime_t'], linestyle='solid', marker='None')
ax.plot_date(csv_df['Date'], trendline, linestyle='--', marker='None', color='red')

# Set the title and labels
ax.set_title('Speed Run Times Over Time')
ax.set_xlabel('Date')
ax.set_ylabel('Real Time')

# Improve the layout
fig.autofmt_xdate()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1445/1621405287.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(csv_df['Date'], csv_df['Realtime_t'], linestyle='solid', marker='None')
# /tmp/ipykernel_1445/1621405287.py:25: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(csv_df['Date'], trendline, linestyle='--', marker='None', color='red')
